# %%
from openai import OpenAI

openai_client = OpenAI()

# %%
response = openai_client.responses.create(
    model="gpt-4o-mini",
    input="tell me a joke about David"
)

# %%
print(response.output_text)
# Out:
# Why did David bring a ladder to the bar?
#
# Because he heard the drinks were on the house!

# %%
messages = [
    {"role": "user", "content": "tell me a joke about Alexey that doesn't have drinks or bar in it"}
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

# %%
print(response.output_text)
# Out:
# Why did Alexey bring a ladder to the meeting?
#
# Because he heard the project was to take things to the next level!

# %%
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "resp_0d76f70ea8f423b20069ef60e8859c8196b2221eee420a46ad",
#   "created_at": 1777295592.0,
#   "error": null,
#   "incomplete_details": null,
#   "instructions": null,
#   "metadata": {},
#   "model": "gpt-4o-mini-2024-07-18",
#   "object": "response",
#   "output": [
#     {
#       "id": "msg_0d76f70ea8f423b20069ef60eb70b88196aac4a0fb137817b2",
#       "content": [
#         {
#           "annotations": [],
#           "text": "Why did Alexey bring a ladder to the meeting?  \n\nBecause he heard the project was to take things to the next level!",
#           "type": "output_text",
#           "logprobs": []
#         }
#       ],
#       "role": "assistant",
#       "status": "completed",
#       "type": "message",
#       "phase": null
#     }
#   ],
#   "parallel_tool_calls": true,
#   "temperature": 1.0,
#   "tool_choice": "auto",
#   "tools": [],
#   "top_p": 1.0,
#   "background": false,
#   "completed_at": 1777295595.0,
#   "conversation": null,
#   "max_output_tokens": null,
#   "max_tool_calls": null,
#   "previous_response_id": null,
#   "prompt": null,
#   "prompt_cache_key": null,
#   "prompt_cache_retention": "in_memory",
#   "reasoning": {
#     "effort": null,
#     "generate_summary": null,
#     "summary": null
#   },
#   "safety_identifier": null,
#   "service_tier": "default",
#   "status": "completed",
#   "text": {
#     "format": {
#       "type": "text"
#     },
#     "verbosity": "medium"
#   },
#   "top_logprobs": 0,
#   "truncation": "disabled",
#   "usage": {
#     "input_tokens": 22,
#     "input_tokens_details": {
#       "cached_tokens": 0
#     },
#     "output_tokens": 27,
#     "output_tokens_details": {
#       "reasoning_tokens": 0
#     },
#     "total_tokens": 49
#   },
#   "user": null,
#   "billing": {
#     "payer": "developer"
#   },
#   "frequency_penalty": 0.0,
#   "moderation": null,
#   "presence_penalty": 0.0,
#   "store": true
# }

# %%
messages = [
    {"role": "user", "content": "tell me a bed time story about a unicorn"}
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

# %%
response.usage
# Out:
# ResponseUsage(input_tokens=50, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=8, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=58)

# %%
MODEL_PRICES = {
    "gpt-4o-mini": {"input": 0.15, "output": 0.60},
    "gpt-5-nano": {"input": 0.075, "output": 0.30},
    "gpt-5-mini": {"input": 0.25, "output": 2.00},
    "gpt-5.2": {"input": 1.75, "output": 14.00},
    "gpt-5.2-pro": {"input": 21.00, "output": 168.00},
}

# %%
def calculate_cost(model_name: str, input_tokens: int, output_tokens: int) -> float:
    prices = MODEL_PRICES[model_name.lower()]
    input_cost = (input_tokens / 1_000_000) * prices["input"]
    output_cost = (output_tokens / 1_000_000) * prices["output"]
    return input_cost + output_cost

# %%
usage = response.usage

cost = calculate_cost(
    model_name="gpt-4o-mini",
    input_tokens=usage.input_tokens,
    output_tokens=usage.output_tokens
)

print(f"Cost: ${cost:.6f}")
# Out:
# Cost: $0.000423

# %%
stream = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages,
    stream=True
)

response = None
for event in stream:
    if hasattr(event, 'delta'):
        print(event.delta, end='')
    if hasattr(event, 'response'):
        response = event.response
# Out:
# **The Starry Night Unicorn**
#
# Once upon a time, in a land where the mountains kissed the sky and the rivers sparkled like diamonds, there lived a gentle unicorn named Luna. Unlike any other unicorn, Luna had a shimmering mane that glowed softly like the moonlight, and her horn sparkled with colors that danced like the stars.
#
# Every evening, as the sun dipped below the horizon, Luna would wander to the highest hill in the enchanted forest to watch the stars appear. She loved the magic of the night, but she had one wish: to discover the source of the twinkling light that filled the sky.
#
# One night, as Luna gazed at the stars, she noticed a particularly bright star that flickered as if it were calling to her. Curious and enchanted, she decided to follow the glow. With each graceful leap, she soared through the air, feeling the soft breeze brush against her coat.
#
# As she traveled, Luna encountered various friends along the way. First, she met Oliver the wise owl, who perched high on an ancient oak. “Where are you off to in such a hurry, dear Luna?” he hooted.
#
# “I’m following the light of a star. I wish to know where it comes from!” she replied, her eyes sparkling with excitement.
#
# Oliver smiled knowingly. “Remember, dear unicorn, the journey is just as important as the destination. Keep your heart open, and the stars will guide you.”
#
# Taking his advice to heart, Luna continued her journey, exploring meadows filled with fragrant flowers and crossing rivers that shimmered under the moonlight. Eventually, she arrived at a tranquil lake, its surface reflecting the stars like a giant mirror. In the middle of the lake was a small island where the source of the twinkling light awaited her.
#
# Luna swam gracefully to the island and discovered a beautiful crystal that pulsed with a warm glow. It was the Heart of the Night Sky, and it held the magic of all the stars above. Overjoyed, Luna approached the crystal, and as she touched it with her horn, it burst into a magnificent display of colors.
#
# Suddenly, the stars began to twinkle brighter, and Luna realized that this magic was not just for her, but for all who gazed up at the sky. With joy in her heart, she spread her wings and soared into the night, illuminating the forest with the colors of the crystal.
#
# As she returned home, she knew that she had discovered not only the source of the light but also the importance of sharing it with others. From that night on, Luna visited the Heart of the Night Sky often, and every time she did, she filled the world with a little more magic.
#
# And so, whenever the night sky twinkled with stars, it was Luna lighting the way for others, ensuring that everyone could dream and believe in the magic around them.
#
# As you drift off to sleep tonight, remember that like Luna, you carry a little spark of light inside you too. Shine bright, and may your dreams be filled with wonder.
#
# **The End.**

# %%
response.usage
# Out:
# ResponseUsage(input_tokens=50, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=8, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=58)

# %%
instructions = "make sure to add emojis"
user_prompt = "tell me a bad time story about a unicorn"

messages = [
    {"role": "system", "content": instructions},
    {"role": "user", "content": user_prompt},
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

# %%
print(response.output_text)
# Out:
# Once upon a time, in a magical forest called Whimsy Woods, there lived a unicorn named Sparklehorn. 🌈✨ Sparklehorn was unlike any other unicorn; he had a beautiful shimmering mane that changed colors and the largest, most dazzling horn in the land. But Sparklehorn had one big problem: he was extremely clumsy. 🦄💫
#
# One sunny day, Sparklehorn decided to host a grand party for all the creatures of the forest. He wanted to impress everyone with his magical treats and games! 🎉🍰 He spent hours decorating his meadow with colorful flowers and hanging glittering lights. But as he trotted around, he accidentally tripped over his own hooves, causing a cascade of flower petals to fly everywhere! 🌼💨
#
# When the day of the party arrived, all the animals gathered, excited for the fun. But just as Sparklehorn was about to greet them, he stumbled again—this time into the big cake he had made! 🎂💥 The cake splattered everywhere, covering the guests in frosting and sprinkles. The animals couldn’t help but giggle, but Sparklehorn felt embarrassed and sad. 😢
#
# Determined to turn things around, Sparklehorn chose to set up a magical game called “Dance with the Stars.” 🌟 But while demonstrating the game, he tripped over his own tail, sending little animals flying everywhere! 🐿️💨 The laughter stopped, and some of the guests began to leave, thinking the party was a disaster.
#
# Feeling defeated, Sparklehorn sat down under a tree, his colorful mane drooping. Suddenly, a wise old owl landed next to him. “Why so glum, Sparklehorn?” she hooted. “You have a gift for making everyone laugh, even if it’s not how you planned.”
#
# Realizing the truth in her words, Sparklehorn decided to embrace his clumsiness. He stood up, apologized for the mishaps, and invited everyone to join him in a silly dance instead! 🎶🦄 Before long, the forest was filled with laughter again, and even though they were all a bit messy, everyone had the time of their lives. 💖
#
# From that day on, Sparklehorn learned that sometimes, the best memories come from the most unexpected moments. And although he remained a bit clumsy, his heart was always full of joy. 🌟💕
#
# And so, the unicorn who once had a “bad time” became the most beloved party planner in Whimsy Woods! 🥳✨
#
# The end! 🌈💖

# %%
instructions = "make sure to add emojis"
user_prompt = "my name is Alexey"

messages = [
    {"role": "system", "content": instructions},
    {"role": "user", "content": user_prompt},
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

print(response.output_text)
# Out:
# Nice to meet you, Alexey! 😊 How can I assist you today?

# %%
response = openai_client.responses.create(
    model='gpt-4o-mini',
    input="What's my name?"
)

print(response.output_text)
# Out:
# I don't have access to personal information, so I can't know your name unless you tell me. What's your name?

# %%
instructions = "make sure to add emojis"
user_prompt = "my name is Alexey"

messages = [
    {"role": "system", "content": instructions},
    {"role": "user", "content": user_prompt},
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

print(response.output_text)
# Out:
# Nice to meet you, Alexey! 😊 How can I assist you today?

# %%
messages.extend(response.output)

# %%
messages
# Out:
# [{'role': 'system', 'content': 'make sure to add emojis'},
#  {'role': 'user', 'content': 'my name is Alexey'},
#  ResponseOutputMessage(id='msg_0cc29cbe680e52b30069ef614ed8b0819e96ca68a61ec41616', content=[ResponseOutputText(annotations=[], text='Nice to meet you, Alexey! 😊 How can I assist you today?', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase=None)]

# %%
messages.append(
    {"role": "user", "content": "what's my name?"}
)

# %%
messages
# Out:
# [{'role': 'system', 'content': 'make sure to add emojis'},
#  {'role': 'user', 'content': 'my name is Alexey'},
#  ResponseOutputMessage(id='msg_0cc29cbe680e52b30069ef614ed8b0819e96ca68a61ec41616', content=[ResponseOutputText(annotations=[], text='Nice to meet you, Alexey! 😊 How can I assist you today?', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase=None),
#  {'role': 'user', 'content': "what's my name?"}]

# %%
response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

print(response.output_text)
# Out:
# Your name is Alexey! 😊
